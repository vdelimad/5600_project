# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
usc_data = pd.read_csv(f'../../../data/raw/space_infrastructure/satellite_data/ucs_satellite_database_5_1_2023.csv')

usc_data
# Out:
#                      Name of Satellite, Alternate Names  \
# 0     1HOPSAT-TD (1st-generation High Optical Perfor...
# 1                               AAC AIS-Sat1 (Kelpie 1)
# 2                                              Aalto-1
# 3                                                 AAt-4
# 4                              ABS-2 (Koreasat-8, ST-3)
# ...                                                 ...
# 7555                                       Ziyuan 1-02C
# 7556                                        Ziyuan 1-2D
# 7557                                    Ziyuan 3 (ZY-3)
# 7558                                         Ziyuan 3-2
# 7559                                         Ziyuan 3-3
#
#      Current Official Name of Satellite Country/Org of UN Registry  \
# 0                            1HOPSAT-TD                         NR
# 1               AAC AIS-Sat1 (Kelpie 1)             United Kingdom
# 2                               Aalto-1                    Finland
# ...

# %%
usc_data.columns
# Out:
# Index(['Name of Satellite, Alternate Names',
#        'Current Official Name of Satellite', 'Country/Org of UN Registry',
#        'Country of Operator/Owner', 'Operator/Owner', 'Users', 'Purpose',
#        'Detailed Purpose', 'Class of Orbit', 'Type of Orbit',
#        'Longitude of GEO (degrees)', 'Perigee (km)', 'Apogee (km)',
#        'Eccentricity', 'Inclination (degrees)', 'Period (minutes)',
#        'Launch Mass (kg.)', ' Dry Mass (kg.) ', 'Power (watts)',
#        'Date of Launch', 'Expected Lifetime (yrs.)', 'Contractor',
#        'Country of Contractor', 'Launch Site', 'Launch Vehicle',
#        'COSPAR Number', 'NORAD Number', 'Comments', 'Unnamed: 28',
#        'Source Used for Orbital Data', 'Source', 'Source.1', 'Source.2',
#        'Source.3', 'Source.4', 'Source.5', 'Source.6'],
#       dtype='object')

# %%
cols_to_drop = ['Comments', 'Unnamed: 28',
       'Source Used for Orbital Data', 'Source', 'Source.1', 'Source.2',
       'Source.3', 'Source.4', 'Source.5', 'Source.6']


usc_data.drop(columns=cols_to_drop, axis=1, inplace=True)

usc_data
# Out:
#                      Name of Satellite, Alternate Names  \
# 0     1HOPSAT-TD (1st-generation High Optical Perfor...
# 1                               AAC AIS-Sat1 (Kelpie 1)
# 2                                              Aalto-1
# 3                                                 AAt-4
# 4                              ABS-2 (Koreasat-8, ST-3)
# ...                                                 ...
# 7555                                       Ziyuan 1-02C
# 7556                                        Ziyuan 1-2D
# 7557                                    Ziyuan 3 (ZY-3)
# 7558                                         Ziyuan 3-2
# 7559                                         Ziyuan 3-3
#
#      Current Official Name of Satellite Country/Org of UN Registry  \
# 0                            1HOPSAT-TD                         NR
# 1               AAC AIS-Sat1 (Kelpie 1)             United Kingdom
# 2                               Aalto-1                    Finland
# ...

# %%
cols_to_rename = {
       'Name of Satellite, Alternate Names': 'name_of_satellite',
       'Current Official Name of Satellite': 'official_name', 
       'Country/Org of UN Registry': 'entity_of_registry',
       'Country of Operator/Owner': 'country_of_operator', 
       'Operator/Owner': 'operator', 
       'Users': 'users', 
       'Purpose': 'purpose',
       'Detailed Purpose': 'detailed_purpose', 
       'Class of Orbit': 'orbit_class', 
       'Type of Orbit': 'orbit_type',
       'Longitude of GEO (degrees)': 'longitude_of_geo_degrees)', 
       'Perigee (km)': 'perigee_km', 
       'Apogee (km)': 'apogee_km',
       'Eccentricity': 'eccentricity', 
       'Inclination (degrees)': 'inclination_degrees', 
       'Period (minutes)': 'period_minutes',
       'Launch Mass (kg.)': 'launch_mass_kg', 
       ' Dry Mass (kg.) ': 'dry_mass_kg', 
       'Power (watts)': 'power_watts',
       'Date of Launch': 'date_of_launch', 
       'Expected Lifetime (yrs.)': 'expected_lifetime_yrs', 
       'Contractor': 'contractor',
       'Country of Contractor': 'contractor_country', 
       'Launch Site': 'launch_site', 
       'Launch Vehicle': 'launch_vehicle',
       'COSPAR Number': 'cospar_number', 
       'NORAD Number': 'norad_number',
       
       }
       
       

usc_data.rename(columns=cols_to_rename, inplace=True)



usc_data
# Out:
#                                       name_of_satellite  \
# 0     1HOPSAT-TD (1st-generation High Optical Perfor...
# 1                               AAC AIS-Sat1 (Kelpie 1)
# 2                                              Aalto-1
# 3                                                 AAt-4
# 4                              ABS-2 (Koreasat-8, ST-3)
# ...                                                 ...
# 7555                                       Ziyuan 1-02C
# 7556                                        Ziyuan 1-2D
# 7557                                    Ziyuan 3 (ZY-3)
# 7558                                         Ziyuan 3-2
# 7559                                         Ziyuan 3-3
#
#                 official_name entity_of_registry country_of_operator  \
# 0                  1HOPSAT-TD                 NR                 USA
# 1     AAC AIS-Sat1 (Kelpie 1)     United Kingdom      United Kingdom
# 2                     Aalto-1            Finland             Finland
# ...

# %%
usc_data.to_csv(f'../../../data/processed/space_infrastructure/satellite_data/ucs_satellite_database.csv', index=False)
